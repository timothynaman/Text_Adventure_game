# %%
#Created on Thu Aug 23 17:52:46 2018

#author: Timothy.Naman

"""
    DocString:
    
    A) Introduction:
    This game is Based on the tv series called "how i met your mother".
    Your name is Tedd Mosby and the engagment of your friends Marshall and 
    lily made you realize that you want to get married. You will go through
    three stages in order to find your soulmate where at the end you either,
    find the one or not.
    
    Round 1: Get to talk to the beautiful girl
    Round 2: Get her on a date 
    Round 3: Finally kiss robin.
    
    B) Known Bugs and/or Errors:
    None.
    
"""


def start(): #defining the start of the game explaining the game and the goal to the user 
    print("""Your name is Tedd Mosby and the engagment of your friends Marshall and 
    lily made you realize that you want to get married. Are you ready to find love? """)
    input("< Press ENTER to continue. >\n")
    name=input(prompt="""Which Ted Mosby nickname do you want use? Shmosby is my favourite! 
                         
               """)#letting the user choose the nickname of the protagonist
    print(f"""
         Barney:" {name}, Where's your suit!? Just once when I say suit up, I wish you'd put on a suit." 
         {name}:"I did that one time."
         Barney:"It was a blazer!."
         {name}: "You know, ever since college it's been Marshall and Lily and me. Now it's going to be Marshall and Lily... and me."
         """)#scene where the user with applied user input is having a conversation with a secondary charachter 
    input("< Press ENTER to continue. >\n")
    print("*Stunning girl enters the Pub*")
    input("< Press ENTER to continue. >\n")
    print(f"""Barney:"SHOTGUN!"
         {name}:"SHOTGUN!"
         """)#letting the user procede between scenes
    input("< Press ENTER to continue. >\n")
    print(f"""Barney:"We said it at the same time,I think its time for a game {name}, 
         whoever wins gets to talk to her, are you down?" yes/no""")    
    
    choice = input(">  \n")
    choice= choice.casefold() #controlling for capitalized input
    if "yes" in choice or "y" in choice:
        games_lst = ["Heads or Tails.",
                  "Rock paper scissors.",
                  "The playbook quiz."]

    #selecting a  random game form a list of games
        import random
        game = games_lst[random.randint(0, len(games_lst) - 1)]
        print(f"\nBarney: {name} you have no chances aginst me, you know i am the best at {game}.\n")
        if game==games_lst[0]:#situation where first item on the list was randomly selected
            import random
            coin_flip = ['heads','tails'] 
            chances = 5
            while chances>0:#giving 3 chances to player
                coin = random.choice(coin_flip)
                choice = input(prompt='\nyou piking heads or tails?\n> ')
                choice= choice.casefold()
                if choice == coin:
                    second_room()#player procedes to next level
                    
                elif choice != coin:
                    chances -=1
                    print(f"Thats how life goes tedd. You have {chances} chances remaining.")

                else:
                    print("\nSomething went wrong.")

            if chances == 0: 
                print(f"You are out of guesses. The coin was {coin}.")
                fail() #in this case the player lose
            else:
                print("\nSomething went wrong.")
        elif game==games_lst[1]:#situation for the second game on the list
            import random
            while True:
                user_action = input(prompt="Enter a choice (Rock, Paper, Scissors): ")
                user_action = user_action.casefold()
                possible_actions = ["rock", "paper", "scissors"]
                computer_action = random.choice(possible_actions)#playng a random choice game every time
                print(f"\nYou chose {user_action}, computer chose {computer_action}.\n")

                if user_action == computer_action:
                    print(f"Both players selected {user_action}. It's a tie!")#situation with user input beign the same as computer's one
                elif user_action == "rock" or "roc" in user_action or "k"in user_action:
                    if computer_action == "scissors":
                        print("Rock smashes scissors! You win!")
                        second_room()#player proceds to next level
                    else:
                        print("Paper covers rock! You lose.")
                elif user_action == "paper" or "pape" in user_action or "p"in user_action :
                    if computer_action == "rock":
                        print("Paper covers rock! You win!")
                        second_room()#player proceds to next level
                    else:
                        print("Scissors cuts paper! You lose.")
                elif user_action == "scissors"or "scissor" in user_action or "s"in user_action:
                    if computer_action == "paper":
                        print("Scissors cuts paper! You win!")
                        second_room()#player proceds to next level
                    else:
                        print("Rock smashes scissors! You lose.")
                play_again = input("Play again? (y/n): ")
                if play_again.lower() != "y": #Asking the player if he wants to start playing again 
                    break
                else:
                    print("I think it was a typo, why dont you try again?")
                    
        elif game==games_lst[2]:#situation for third game
            print("Welcome to the playbook Quiz")
            answer=input(prompt=f"""Barney:"Are you ready to play the Quiz {name}?, you need 1 correct answer to win" (yes/no) :""")
            score=0
            total_questions=3

            if answer.lower()=="yes": #player wants to play the game 
                answer=input(prompt=f"""Barney: Question one {name}, Do i like more blond hair or red hair girls?""")
                if answer.lower()=="blond":
                    score += 1
                    print("correct")
                else:
                    print("Wrong Answer :(") #only correct answer impact score


                answer=input(prompt=f"""Barney: Question two {name}, do the playbook contains a play where I go up to a girl and claim I works for a secret government agency called 'Secret NASA' ?" yes/no:""")
                if answer.lower()=="yes":
                    score += 1 #score number increase
                    print("correct")
                else:
                    print("Wrong Answer :(")

                answer=input(prompt=f"Barney: Question three {name}, Is 'the missing dog' a play in the playbook? yes/no:")
                if answer.lower()=="no": #correct answer is no in this case
                    score += 1
                    print("correct")
                else:
                    print("Wrong Answer :(")

            print('Thankyou for Playing this small quiz game, you attempted',score,"questions correctly!")
            if score!=0: #player guessd at least one question
                second_room()
            else:
                fail()
            
        else:
            print("\nSomething went wrong.")    
    elif "no" in choice: #player does not want to continue the game 
        print("\nToo bad barney get to talk robin you migh miss the love of your life\n")
    else:
                print("\nI think that was a typo, try again!.")
                start()#redirecting player at the start


            



def second_room(): #defining the second level 
    print(f"""You won  and you are talking to her.., 
            Ted:Your name is Robin.
            Robyn:Yeah, with a "y".
            Ted:Oh, Yobin.
            Ted: So what do you do? 
            Robin: I'm a reporter for Metro News 1.
            Ted: Hey, you wanna have dinner with me Saturday night?
            Robin: Yeah, what the hell, I don't know why but i like you.
                """)
    input("< Press ENTER to continue. >\n") #user input to continue
    while True:
        print("Where are you thinking to go for your first date with Robin")
        print("""
            1. Pub
            2. Restaurant
            3. Footbal game
             """)
        choice = input(" > ")
        choice= choice.casefold() #controlling for upper case user input
        if "1" in choice or "pub" in choice:
            print ("\nWho would go to a pub for a first date? weirdo! maybe you should try again!\n")
        elif "2"in choice or "restaurant" in choice or "rest"in choice:
            print(f"\nGreat choice, Robin loves restaurants especially french ones! \n")
            while True:#user will never fail here
                print(f""" Robin loved the french restaurant ;),and invited you at hers apartment. Right now you are very nervous,       
                you like her... what are you gonna do next?
                        1. Try to kiss her
                        2. Make a funny joke and hope for the best
                        3. Pet her dogs 
                        4. Ask her about her life and wait to kiss her

                                """)
                choice=input("\n") #user input from options
                if "1"in choice or "try to kiss her"in choice or "try to" in choice:
                    print("\nI think you are rushing tedd! maybe you should try again!\n")  
                elif "2" in choice or "make a funny joke" in choice or "make a funny joke and hope for the best" in choice:
                    print ("\nYou are not really great with jokes and this was not funny at all!maybe you should try again!\n") 
                elif "3" in choice or "Pet her dogs" in choice or "Pet dogs"in choice:
                    print ("\nThey bark at you and you get scared!maybe you should try again!\n") 
                elif "4" in choice or "Ask her about her life and wait to kiss her" in choice or "Ask her about her life"in choice:
                    print ("\nYou talk all night and she loved your kindness for not making any rushed move!\n")

                else: #else in case input is wrong
                    print("\nSomething went wrong.maybe you should try again!")
        elif "3" in choice or "football game" in choice or "game"in choice or "football" in choice:
            print ("\nRobin hates football, she loves hockey!maybe you should try again!\n") 
        else:
            print("\nSomething went wrong.")
            second_room() #user go to the third level

def third_room(): #defining third stage
    print(f""" Marshal, lily and Barney believe you should have kissed her, and they convinced you to make a big move, what is your plan?
                1. Sing her a serenade
                2. gift her a puppy dog
                3. Steal the blue horn you saw in your first date
                4. subscribe at the same gim as herjust to meet her
                
                        """)
    choice=input("\n")#user input to choose the caction to take
    if "1"in choice or "Sing her a serenade"in choice or "Sing" in choice:
        print("\nYour voice is terrible tedd, find another way!\n") 
        third_room() #user will restart this level 
    elif "2" in choice or "gift her a puppy dog" in choice or "gift" in choice:
        print ("\nShe has already five dogs that was not a bold move!find another way!\n")
        third_room()
    elif "3" in choice or "Steal the blue horn you saw in your first date" in choice or "Steal"in choice:#user get to next stage
        print ("\n The blue horn eas such a great move, she quite into you now..!\n")
        input("< Press ENTER to continue. >\n")
        print(f""" This is your chance, your date with Robin resume and she is telling you how you impressed her so now.. 
                1. you tell her you love her
                2. Ask her to marry you
                3. Shut her up and slowly get closer to kiss her
                        """)
        choice=input("\n")#user input to choose final move
        if "1"in choice or "you tell her you love her"in choice or "I love you" in choice:
            print("\n The romanticism that was in the air disappears \n") 
            fail()#player will fail in this case
        elif "2" in choice or "Ask her to marry you" in choice or "would you marry me?" in choice:
            print ("\nshe kicks you out, you scard her!\n")
            fail()
        elif "3" in choice or "Shut her up and slowly get closer to kiss her" in choice or "kiss"in choice:
            print ("\she stopped talking and slowly approaches you\n")
            win()#player will win in this case
        else:
            print("\nI think that was a typo, try again!")
        
        
    elif "4" in choice or "subscribe at the same gim as herjust to meet her" in choice or "subscribe"in choice:
        print ("\nYou are so close of beign a stalker tedd!find another way!\n")
        third_room()#user can try again
    else:
        print("\nI think that was a typo, try again!\n")
        third_room() 

def fail(): #defining the loosing room
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
    print(""" 
  ___                                  
 / __|__ _ _ __  ___   _____ _____ _ _ 
| (_ / _` | '  \/ -_) / _ \ V / -_) '_|
 \___\__,_|_|_|_\___| \___/\_/\___|_|  
            """)# printing an ASCII art
    play_again2 = input("Play again? (y/n): ")
    if play_again2.lower() == "y":
        start()
    elif play_again2.lower() != "y":
        exit(0)#kernel will stop 
    else:
        print("Are you sure it wasn't a typo?")
        fail()

def win():#defining winning room
    import time
    count=3
    while count>0:
        print(count)
        count -=1 #countdown for kiss
        time.sleep(1)
    if count ==0:
        print(""" 
           .,,,,,,,,,,.
         ,;;;;;;;;;;;;;;,
       ,;;;;;;;;;;;)));;(((,,;;;,,_
      ,;;;;;;;;;;'      |)))))))))))\\
      ;;;;;;/ )''    - /,)))((((((((((\
   
      ;;;;' \        ~|\  ))))))))))))))
      /     /         |   ((((((((((((((
    /'      \      _/~'    ')|()))))))))
  /'         `\   />     o_/)))((((((((
 /          /' `~~(____ /  ()))))))))))
|     ---,   \        \     ((((((((((
          `\   \~-_____|      ))))))))
            `\  |      |_.---.  \
                """)
    play_again2 = input("Play again? (y/n): ")#player can play again
    if play_again2.lower() == "y":
        start()
    elif play_again2.lower() != "y":
        exit(0)
    else:
        print("Are you sure it wasn't a typo?")
        win()#player will try again in this room


start()#starting the game
# Out:
# Your name is Tedd Mosby and the engagment of your friends Marshall and
#     lily made you realize that you want to get married. Are you ready to find love?
# < Press ENTER to continue. >
#
# Which Ted Mosby nickname do you want use? Shmosby is my favourite!
#
#
#
#          Barney:" , Where's your suit!? Just once when I say suit up, I wish you'd put on a suit."
#          :"I did that one time."
#          Barney:"It was a blazer!."
#          : "You know, ever since college it's been Marshall and Lily and me. Now it's going to be Marshall and Lily... and me."
#
# < Press ENTER to continue. >
#
# *Stunning girl enters the Pub*
# < Press ENTER to continue. >
#
# Barney:"SHOTGUN!"
#          :"SHOTGUN!"
#
# < Press ENTER to continue. >
#
# Barney:"I think its time for a game ,
#          whoever wins gets to talk to her, are you down?" yes/no
# >
# yes
#
# Barney:  you have no chances aginst me, you know i am the best at Rock paper scissors..
#
# ...
